# %%
import pandas as pd # pandas
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
# from sklearn import impute
from  scipy.stats import skew, kurtosis, shapiro
import datetime
import time

plt.rc('axes', linewidth=2)
plt.rc('axes', labelsize= 16)
plt.rc('axes',titlesize = 18)
plt.rc('legend',fontsize=14)
plt.rc('xtick', labelsize=16) 
plt.rc('ytick', labelsize=16) 
plt.rc('figure',figsize=(10,8),titleweight ='bold')
# plt.rc('lines',linewidth = 2)

def figure_layout(figsize=(10,8),titel="",xlabel="",ylabel="",fontsize_titel=18,fontsize_axis=16,fontsize_legend=14,fontsize_ticks=16):
    plt.figure(figsize=figsize)
    ax1 = plt.gca()
    plt.rc('legend',fontsize=fontsize_legend)
    plt.title(titel, fontsize=fontsize_titel, fontweight = 'bold')
    plt.grid(True)
    plt.xlabel(xlabel, fontsize=fontsize_axis)
    plt.ylabel(ylabel, fontsize=fontsize_axis)
    for tick in ax1.xaxis.get_major_ticks():
            tick.label1.set_fontsize(fontsize_ticks)
    #         tick.label1.set_fontweight('bold')
    for tick in ax1.yaxis.get_major_ticks():
        tick.label1.set_fontsize(fontsize_ticks)
    #     tick.label1.set_fontweight('bold')
    
    return ax1

# %%
attributes = pd.read_csv("D:\Onedrive\Leuven\Final project\data\\addinfo.csv",index_col = "meter_id")
print(attributes.shape)
amountMeters = attributes.shape[0]
attributes.head(100)
# Out:
# (2143, 23)
#                                                   dwelling_type  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43  semi_detached_house
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41       terraced_house
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339  semi_detached_house
# 0x2b538a5ebfc3780aef25227267063cb6410d943b       detached_house
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7                  NaN
# ...                                                         ...
# 0xd33e5ad8e928a17e08384bea04c0d583edc77c2c       terraced_house
# 0xc053c89ca63bad876806ebd23e6cbcdf71b8b1a3                  NaN
# 0xcef4d8d3c2bde0565ceac3814cf8ef43a25b4963                  NaN
# 0xebc6019ab4ef2300113d585a6fb9e85656342558       terraced_house
# 0x3fa8effb7c96a42b8600e5e8eace26cbdde14c46       detached_house
#
#                                             num_occupants  num_bedrooms  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43            NaN           3.0
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41            NaN           2.0
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339            NaN           NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b            NaN           4.0
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7            NaN           NaN
# ...                                                   ...           ...
# 0xd33e5ad8e928a17e08384bea04c0d583edc77c2c            NaN           3.0
# 0xc053c89ca63bad876806ebd23e6cbcdf71b8b1a3            NaN           NaN
# 0xcef4d8d3c2bde0565ceac3814cf8ef43a25b4963            NaN           2.0
# 0xebc6019ab4ef2300113d585a6fb9e85656342558            NaN           3.0
# 0x3fa8effb7c96a42b8600e5e8eace26cbdde14c46            NaN           5.0
#
#                                            heating_fuel hot_water_fuel  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43          NaN            NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41          NaN            NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339          NaN            NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b          NaN            NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7          NaN            NaN
# ...                                                 ...            ...
# 0xd33e5ad8e928a17e08384bea04c0d583edc77c2c          NaN            NaN
# 0xc053c89ca63bad876806ebd23e6cbcdf71b8b1a3          NaN            NaN
# 0xcef4d8d3c2bde0565ceac3814cf8ef43a25b4963          NaN            NaN
# 0xebc6019ab4ef2300113d585a6fb9e85656342558          NaN            NaN
# 0x3fa8effb7c96a42b8600e5e8eace26cbdde14c46          NaN            NaN
#
#                                            boiler_age loft_insulation  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43        NaN             NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41        NaN             NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339        NaN             NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b        NaN             NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7        NaN             NaN
# ...                                               ...             ...
# 0xd33e5ad8e928a17e08384bea04c0d583edc77c2c        NaN             NaN
# 0xc053c89ca63bad876806ebd23e6cbcdf71b8b1a3        NaN             NaN
# 0xcef4d8d3c2bde0565ceac3814cf8ef43a25b4963        NaN             NaN
# 0xebc6019ab4ef2300113d585a6fb9e85656342558        NaN             NaN
# 0x3fa8effb7c96a42b8600e5e8eace26cbdde14c46        NaN             NaN
#
#                                            wall_insulation  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43             NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41             NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339             NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b             NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7             NaN
# ...                                                    ...
# 0xd33e5ad8e928a17e08384bea04c0d583edc77c2c             NaN
# 0xc053c89ca63bad876806ebd23e6cbcdf71b8b1a3             NaN
# 0xcef4d8d3c2bde0565ceac3814cf8ef43a25b4963             NaN
# 0xebc6019ab4ef2300113d585a6fb9e85656342558             NaN
# 0x3fa8effb7c96a42b8600e5e8eace26cbdde14c46             NaN
#
#                                            heating_temperature  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43                 NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41                 NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339                 NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b                 NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7                 NaN
# ...                                                        ...
# 0xd33e5ad8e928a17e08384bea04c0d583edc77c2c                 NaN
# 0xc053c89ca63bad876806ebd23e6cbcdf71b8b1a3                 NaN
# 0xcef4d8d3c2bde0565ceac3814cf8ef43a25b4963                 NaN
# 0xebc6019ab4ef2300113d585a6fb9e85656342558                 NaN
# 0x3fa8effb7c96a42b8600e5e8eace26cbdde14c46                 NaN
#
#                                            efficient_lighting_percentage  ...  \
# meter_id                                                                  ...
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43                           NaN  ...
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41                           NaN  ...
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339                           NaN  ...
# 0x2b538a5ebfc3780aef25227267063cb6410d943b                           NaN  ...
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7                           NaN  ...
# ...                                                                  ...  ...
# 0xd33e5ad8e928a17e08384bea04c0d583edc77c2c                           NaN  ...
# 0xc053c89ca63bad876806ebd23e6cbcdf71b8b1a3                           NaN  ...
# 0xcef4d8d3c2bde0565ceac3814cf8ef43a25b4963                           NaN  ...
# 0xebc6019ab4ef2300113d585a6fb9e85656342558                           NaN  ...
# 0x3fa8effb7c96a42b8600e5e8eace26cbdde14c46                           NaN  ...
#
#                                             refrigerator  tumble_dryer  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43           NaN           NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41           NaN           NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339           NaN           NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b           NaN           NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7           NaN           NaN
# ...                                                  ...           ...
# 0xd33e5ad8e928a17e08384bea04c0d583edc77c2c           NaN           NaN
# 0xc053c89ca63bad876806ebd23e6cbcdf71b8b1a3           NaN           NaN
# 0xcef4d8d3c2bde0565ceac3814cf8ef43a25b4963           NaN           NaN
# 0xebc6019ab4ef2300113d585a6fb9e85656342558           NaN           NaN
# 0x3fa8effb7c96a42b8600e5e8eace26cbdde14c46           NaN           NaN
#
#                                             washing_machine  game_console  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43              NaN           NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41              NaN           NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339              NaN           NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b              NaN           NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7              NaN           NaN
# ...                                                     ...           ...
# 0xd33e5ad8e928a17e08384bea04c0d583edc77c2c              NaN           NaN
# 0xc053c89ca63bad876806ebd23e6cbcdf71b8b1a3              NaN           NaN
# 0xcef4d8d3c2bde0565ceac3814cf8ef43a25b4963              NaN           NaN
# 0xebc6019ab4ef2300113d585a6fb9e85656342558              NaN           NaN
# 0x3fa8effb7c96a42b8600e5e8eace26cbdde14c46              NaN           NaN
#
#                                             laptop  pc  router  set_top_box  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43     NaN NaN     NaN          NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41     NaN NaN     NaN          NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339     NaN NaN     NaN          NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b     NaN NaN     NaN          NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7     NaN NaN     NaN          NaN
# ...                                            ...  ..     ...          ...
# 0xd33e5ad8e928a17e08384bea04c0d583edc77c2c     NaN NaN     NaN          NaN
# 0xc053c89ca63bad876806ebd23e6cbcdf71b8b1a3     NaN NaN     NaN          NaN
# 0xcef4d8d3c2bde0565ceac3814cf8ef43a25b4963     NaN NaN     NaN          NaN
# 0xebc6019ab4ef2300113d585a6fb9e85656342558     NaN NaN     NaN          NaN
# 0x3fa8effb7c96a42b8600e5e8eace26cbdde14c46     NaN NaN     NaN          NaN
#
#                                             tablet  tv
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43     NaN NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41     NaN NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339     NaN NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b     NaN NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7     NaN NaN
# ...                                            ...  ..
# 0xd33e5ad8e928a17e08384bea04c0d583edc77c2c     NaN NaN
# 0xc053c89ca63bad876806ebd23e6cbcdf71b8b1a3     NaN NaN
# 0xcef4d8d3c2bde0565ceac3814cf8ef43a25b4963     NaN NaN
# 0xebc6019ab4ef2300113d585a6fb9e85656342558     NaN NaN
# 0x3fa8effb7c96a42b8600e5e8eace26cbdde14c46     NaN NaN
#
# [100 rows x 23 columns]

# %% [markdown]
# There are 2143 meters with additional information of at least one of the 23 attributes.

# %%
# It is possible to look to the month December where all series have data to investigate the effect of an attribute. 
for col in attributes.columns:
    total = amountMeters - attributes[col].isnull().sum()
    print("Attribute %s has %s filled places." % (col, total))
# Out:
# Attribute dwelling_type has 1702 filled places.
# Attribute num_occupants has 74 filled places.
# Attribute num_bedrooms has 1859 filled places.
# Attribute heating_fuel has 78 filled places.
# Attribute hot_water_fuel has 76 filled places.
# Attribute boiler_age has 74 filled places.
# Attribute loft_insulation has 75 filled places.
# Attribute wall_insulation has 75 filled places.
# Attribute heating_temperature has 74 filled places.
# Attribute efficient_lighting_percentage has 73 filled places.
# Attribute dishwasher has 76 filled places.
# Attribute freezer has 70 filled places.
# Attribute fridge_freezer has 70 filled places.
# Attribute refrigerator has 73 filled places.
# Attribute tumble_dryer has 76 filled places.
# Attribute washing_machine has 76 filled places.
# Attribute game_console has 72 filled places.
# Attribute laptop has 70 filled places.
# Attribute pc has 70 filled places.
# Attribute router has 69 filled places.
# Attribute set_top_box has 70 filled places.
# Attribute tablet has 70 filled places.
# Attribute tv has 75 filled places.

# %%
attributes.loc[attributes.index[0],"dwelling_type"]
# Out:
# 'semi_detached_house'

# %%
# Assessement of the type of house
for row in attributes.index:
    dwellingType = attributes.loc[row,"dwelling_type"]
    occupants = attributes.loc[row,"num_occupants"]
    bedrooms = attributes.loc[row,"num_bedrooms"]
    if not np.isnan(occupants):
        print("Dwelling type: %s"%dwellingType)
        print("#occupants: %s"%occupants)
        print("Number of bedrooms:%s\n"%bedrooms)
# Out:
# Dwelling type: detached_house
# #occupants: 2.0
# Number of bedrooms:4.0
#
# Dwelling type: bungalow
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:4.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: detached_house
# #occupants: 2.0
# Number of bedrooms:4.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: bungalow
# #occupants: 4.0
# Number of bedrooms:5.0
#
# Dwelling type: flat
# #occupants: 2.0
# Number of bedrooms:1.0
#
# Dwelling type: detached_house
# #occupants: 2.0
# Number of bedrooms:4.0
#
# Dwelling type: terraced_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: detached_house
# #occupants: 2.0
# Number of bedrooms:4.0
#
# Dwelling type: detached_house
# #occupants: 2.0
# Number of bedrooms:4.0
#
# Dwelling type: flat
# #occupants: 2.0
# Number of bedrooms:1.0
#
# Dwelling type: terraced_house
# #occupants: 3.0
# Number of bedrooms:3.0
#
# Dwelling type: detached_house
# #occupants: 2.0
# Number of bedrooms:4.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 4.0
# Number of bedrooms:3.0
#
# Dwelling type: bungalow
# #occupants: 1.0
# Number of bedrooms:2.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: detached_house
# #occupants: 3.0
# Number of bedrooms:5.0
#
# Dwelling type: terraced_house
# #occupants: 1.0
# Number of bedrooms:2.0
#
# Dwelling type: semi_detached_house
# #occupants: 1.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 4.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 4.0
# Number of bedrooms:4.0
#
# Dwelling type: detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 4.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:4.0
#
# Dwelling type: semi_detached_house
# #occupants: 3.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 3.0
# Number of bedrooms:3.0
#
# Dwelling type: detached_house
# #occupants: 2.0
# Number of bedrooms:4.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 4.0
# Number of bedrooms:3.0
#
# Dwelling type: bungalow
# #occupants: 2.0
# Number of bedrooms:2.0
#
# Dwelling type: detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 1.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: terraced_house
# #occupants: 1.0
# Number of bedrooms:2.0
#
# Dwelling type: terraced_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: terraced_house
# #occupants: 2.0
# Number of bedrooms:5.0
#
# Dwelling type: flat
# #occupants: 1.0
# Number of bedrooms:1.0
#
# Dwelling type: detached_house
# #occupants: 4.0
# Number of bedrooms:4.0
#
# Dwelling type: detached_house
# #occupants: 2.0
# Number of bedrooms:4.0
#
# Dwelling type: bungalow
# #occupants: 2.0
# Number of bedrooms:2.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: terraced_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:2.0
#
# Dwelling type: terraced_house
# #occupants: 4.0
# Number of bedrooms:3.0
#
# Dwelling type: terraced_house
# #occupants: 3.0
# Number of bedrooms:3.0
#
# Dwelling type: terraced_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: detached_house
# #occupants: 4.0
# Number of bedrooms:5.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: detached_house
# #occupants: 3.0
# Number of bedrooms:5.0
#
# Dwelling type: semi_detached_house
# #occupants: 4.0
# Number of bedrooms:4.0
#
# Dwelling type: semi_detached_house
# #occupants: 1.0
# Number of bedrooms:3.0
#
# Dwelling type: detached_house
# #occupants: 2.0
# Number of bedrooms:4.0
#
# Dwelling type: detached_house
# #occupants: 4.0
# Number of bedrooms:5.0
#
# Dwelling type: flat
# #occupants: 2.0
# Number of bedrooms:2.0
#
# Dwelling type: semi_detached_house
# #occupants: 3.0
# Number of bedrooms:5.0
#
# Dwelling type: bungalow
# #occupants: 2.0
# Number of bedrooms:4.0
#
# Dwelling type: terraced_house
# #occupants: 3.0
# Number of bedrooms:3.0
#
# Dwelling type: bungalow
# #occupants: 3.0
# Number of bedrooms:2.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: bungalow
# #occupants: 2.0
# Number of bedrooms:4.0
#
# Dwelling type: detached_house
# #occupants: 2.0
# Number of bedrooms:3.0
#
# Dwelling type: detached_house
# #occupants: 3.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 4.0
# Number of bedrooms:4.0
#
# Dwelling type: semi_detached_house
# #occupants: 4.0
# Number of bedrooms:3.0
#
# Dwelling type: semi_detached_house
# #occupants: 2.0
# Number of bedrooms:2.0
#
# Dwelling type: bungalow
# #occupants: 2.0
# Number of bedrooms:2.0
#
# Dwelling type: terraced_house
# #occupants: 2.0
# Number of bedrooms:2.0

# %%
a = attributes.isnull().sum(axis=1)
full_names = a[a==0].index
attributes.loc[full_names[2]]
# Out:
# dwelling_type                    semi_detached_house
# num_occupants                                      2
# num_bedrooms                                       3
# heating_fuel                                     gas
# hot_water_fuel                                   gas
# boiler_age                                       old
# loft_insulation                                    y
# wall_insulation                             y_cavity
# heating_temperature                         18_to_20
# efficient_lighting_percentage              75_to_100
# dishwasher                                         1
# freezer                                            0
# fridge_freezer                                     1
# refrigerator                                       1
# tumble_dryer                                       1
# washing_machine                                    1
# game_console                                       0
# laptop                                             1
# pc                                                 1
# router                                             1
# set_top_box                                        1
# tablet                                             2
# tv                                                 4
# Name: 0x748cad7867e108022b8692e6cf833b2e09efa5df, dtype: object

# %%
print("Amount of meters with full household data: %s."%full_names.shape[0])
# Out:
# Amount of meters with full household data: 51.

# %% [markdown]
# # Correlation between consumption and household characteristics .

# %%
originalData = pd.read_csv("D:\Onedrive\Leuven\Final project\data\consumption.csv",index_col = "meter_id")

# %%
originalData_T = originalData.transpose()
originalData_T.index = pd.to_datetime(originalData_T.index)

# %%
# Estimate the missing data based on previous and future observations
def estimated_mean_signal(test):
    # subsitude if necessary the first of january or the last day of december (general) then
    for col_ID in test.columns:
        missing_index = test.loc[pd.isna(test[col_ID]), :].index
        meanOfSerie = test[col_ID].mean()
        for date in missing_index:
            # if date.dayofyear == 1 or date.dayofyear == 365:
            if date.day == 1 or date.day == 31:
                estimation = meanOfSerie
                test.loc[date,col_ID] = estimation
    
    # subsitude the rest of the days
    for col_ID in test.columns:
        missing_index = test.loc[pd.isna(test[col_ID]), :].index
        for date in missing_index:
            n = 0
            next_measure_index = date + datetime.timedelta(days= 1)
            next_measure_value = test.loc[next_measure_index,col_ID]
            
            previous_measure_index = date + datetime.timedelta(days= -1)
            previous_measure_value = test.loc[previous_measure_index,col_ID]

            while np.isnan(next_measure_value) or np.isnan(previous_measure_value):
                n += 1
                            
                if np.isnan(next_measure_value) and np.isnan(previous_measure_value):

                    next_measure_index = date + datetime.timedelta(days= n + 1)
                    next_measure_value = test.loc[next_measure_index,col_ID]
                    previous_measure_index = date + datetime.timedelta(days= -1*(n + 1))
                    previous_measure_value = test.loc[next_measure_index,col_ID]
                
                elif np.isnan(next_measure_value):
                    next_measure_index = date + datetime.timedelta(days= n + 1)
                    next_measure_value = test.loc[next_measure_index,col_ID]

                elif np.isnan(previous_measure_value):
                    previous_measure_index = date + datetime.timedelta(days= -1*(n + 1))
                    previous_measure_value = test.loc[next_measure_index,col_ID]

                else:
                    raise Exception("Should have been excepted by one of the previous cases.")
                

            estimation = (next_measure_value + previous_measure_value)/2
            test.loc[date,col_ID] = estimation

# %%
originalDecember = originalData_T[originalData_T.index.month_name() == "December"]

# %%
originalDecember_NM = originalDecember.copy(deep=True)
originalDecember_NM.isnull().sum(axis=0).sum()
# Out:
# 1265472

# %%
estimated_mean_signal(originalDecember_NM)
originalDecember_NM.to_csv("D:\Onedrive\Leuven\Final project\data\WrittenData\\originalDecember_no_missing.csv")

# %%
axis = figure_layout(figsize=(10,8),titel="Replacing missing values",xlabel="",ylabel="Consumption [KWh]",fontsize_titel=18,fontsize_axis=16,fontsize_legend=14,fontsize_ticks=16)
originalDecember_NM.iloc[:,0].plot(ax=axis,legend= "Replaced values")
originalDecember.iloc[:,0].plot(ax=axis,legend= "Missing values")
plt.show()

# %%
originalDecember_NM.isnull().sum(axis=0).sum()
# Out:
# 0

# %%
originalDecember_NM = pd.read_csv("D:\Onedrive\Leuven\Final project\data\WrittenData\\originalDecember_no_missing.csv",index_col='Unnamed: 0',parse_dates=['Unnamed: 0'])

# %% [markdown]
# ## Correlatie

# %%
decemberConsumption = originalDecember_NM.sum(axis=0)

# %%
# ax = axes[0][0]
# ax.set_title("Dwelling Type")
# ax.scatter(['try','try','try'], [52,10,25])
# ax.scatter(['try2','try2','try2'], [52,10,25])

# plt.show()

# %%
def box_plot(axis,data,name_plot):
    bp = axis.boxplot(data,patch_artist=True)
    val = [item.get_ydata() for item in bp['medians']]
    print("medians:")
    print(val)
    # change outline color, fill color and linewidth of the boxes
    for box in bp['boxes']:
        box.set(color='#7570b3', linewidth=2)
        box.set(facecolor='#1b9e77')
    for whisker in bp['whiskers']:
        whisker.set(color='#7570b3', linewidth=2)
    for cap in bp['caps']:
        cap.set(color='#7570b3', linewidth=2)
    for median in bp['medians']:
        median.set(color='#b2df8a', linewidth=2)
    for flier in bp['fliers']:
        flier.set(marker='o', color='#e7298a', alpha=0.5)
    axis.set_xticklabels(name_plot)

# %%
# def box_plot(axis,data,name_plot):
	
#     bp = axis.boxplot(data,patch_artist=True)
#     print("stijn")
#     ## change outline color, fill color and linewidth of the boxes
#     for box in bp['boxes']:
# 		# change outline color
# 		box.set(color='#7570b3', linewidth=2)
# 		# change fill color
# 		box.set(facecolor='#1b9e77')

#     ## change color and linewidth of the whiskers
#     for whisker in bp['whiskers']:
#         whisker.set(color='#7570b3', linewidth=2)

#     ## change color and linewidth of the caps
#     for cap in bp['caps']:
# 		cap.set(color='#7570b3', linewidth=2)

# 	## change color and linewidth of the medians
#     for median in bp['medians']:
#         median.set(color='#b2df8a', linewidth=2)

# 	## change the style of fliers and their fill
#     for flier in bp['fliers']:
#         flier.set(marker='o', color='#e7298a', alpha=0.5)
#     axis.set_xticklabels(name_plot)

# %% [markdown]
# ### Dwelling type

# %%
def plot_samples(column_name = "dwelling_type", titel = "Dwelling Type", list_var =  ["flat","bungalow","detached_house","semi_detached_house","terraced_house"],size = (18,8)):
    # (_,axes) = plt.subplots(2,3)
    ax = figure_layout(figsize=size,titel=titel,ylabel="Monthly Consumption [kWh]",fontsize_axis = 20,fontsize_ticks = 20)
    # ax = axes[0][0]
    # ax.set_title()
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
    i = 0
    for typ in list_var:      
        names = attributes.index[np.array(attributes.loc[:,column_name]) == typ].values
        for meter_name in names:
            ax.scatter(typ,decemberConsumption.loc[meter_name],c=colors[i])
        i = i +1
    plt.show()

# %%
plot_samples()

# %%
def new_box_plot(data = [[],[],[],[],[]],column_name = 'dwelling_type', name_plot = ["flat","bungalow","detached_house","semi_detached_house","terraced_house"],titel = "Dwelling Type",list_var = ["flat","bungalow","detached_house","semi_detached_house","terraced_house"],lim=1000,size = (18,8)): 

    new_ax = figure_layout(figsize=size,titel=titel,ylabel="Monthly Consumption [kWh]",fontsize_axis = 20, fontsize_ticks = 20)
    i = 0
    for typ in list_var:   
        names = attributes.index[np.array(attributes.loc[:,column_name]) == typ].values
        for meter_name in names:
            con = decemberConsumption.loc[meter_name]
            data[i].insert(0,con)
        i = i + 1
    new_ax.set_ylim([0,lim])
    box_plot(axis = new_ax,data= data,name_plot=name_plot)
    return data

# %%
data = new_box_plot()
# fname = "D:\Onedrive\Leuven\Final project\data\WrittenData\\picture.png"
# plt.savefig(fname, dpi=None, facecolor='w', edgecolor='w',orientation='portrait', papertype=None, format=None,transparent=False, bbox_inches=None, pad_inches=0.1,metadata=None)
# Out:
# medians:
# [array([250.15621739, 250.15621739]), array([275.5333913, 275.5333913]), array([357.72169565, 357.72169565]), array([287.91878261, 287.91878261]), array([302.84517391, 302.84517391])]

# %%
means = []
for i in range(len(data)):
    means.append(np.mean(data[i]))
print(means)
# Out:
# [348.5726605814489, 360.18792840228275, 430.7348272694332, 358.4506524326497, 374.10743466406774]

# %% [markdown]
# ### Nr. occupants

# %%
attributes.head()
# Out:
#                                                   dwelling_type  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43  semi_detached_house
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41       terraced_house
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339  semi_detached_house
# 0x2b538a5ebfc3780aef25227267063cb6410d943b       detached_house
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7                  NaN
#
#                                             num_occupants  num_bedrooms  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43            NaN           3.0
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41            NaN           2.0
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339            NaN           NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b            NaN           4.0
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7            NaN           NaN
#
#                                            heating_fuel hot_water_fuel  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43          NaN            NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41          NaN            NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339          NaN            NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b          NaN            NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7          NaN            NaN
#
#                                            boiler_age loft_insulation  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43        NaN             NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41        NaN             NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339        NaN             NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b        NaN             NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7        NaN             NaN
#
#                                            wall_insulation  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43             NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41             NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339             NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b             NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7             NaN
#
#                                            heating_temperature  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43                 NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41                 NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339                 NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b                 NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7                 NaN
#
#                                            efficient_lighting_percentage  ...  \
# meter_id                                                                  ...
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43                           NaN  ...
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41                           NaN  ...
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339                           NaN  ...
# 0x2b538a5ebfc3780aef25227267063cb6410d943b                           NaN  ...
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7                           NaN  ...
#
#                                             refrigerator  tumble_dryer  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43           NaN           NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41           NaN           NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339           NaN           NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b           NaN           NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7           NaN           NaN
#
#                                             washing_machine  game_console  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43              NaN           NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41              NaN           NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339              NaN           NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b              NaN           NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7              NaN           NaN
#
#                                             laptop  pc  router  set_top_box  \
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43     NaN NaN     NaN          NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41     NaN NaN     NaN          NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339     NaN NaN     NaN          NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b     NaN NaN     NaN          NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7     NaN NaN     NaN          NaN
#
#                                             tablet  tv
# meter_id
# 0x02b7418b821b2edeeb2baa23ba1580566b4b0e43     NaN NaN
# 0xaf32b2b497e9eb9c3f3de907aedc6a7914a11f41     NaN NaN
# 0xdd45ab28a7a40eadc04607d6da42e5ad923b1339     NaN NaN
# 0x2b538a5ebfc3780aef25227267063cb6410d943b     NaN NaN
# 0xee032ed498c9e99a4c65e0f39896fb30e513c6b7     NaN NaN
#
# [5 rows x 23 columns]

# %%
plot_samples(column_name = "num_occupants", titel = "# Occupants", list_var =  [1,2,3,4],size = (18,8))

# %%
data = new_box_plot(data = [[],[],[],[]],column_name = 'num_occupants', name_plot = ["One", "Two", "Three", "Four"],titel = "# Occupants",list_var = [1,2,3,4],lim=2000,size = (18,8))
# Out:
# medians:
# [array([151.30965217, 151.30965217]), array([317.18868478, 317.18868478]), array([402.61766304, 402.61766304]), array([556.67330435, 556.67330435])]

# %%
means = []
for i in range(len(data)):
    means.append(np.mean(data[i]))
print(means)
# Out:
# [154.1193850931677, 447.2281200227945, 536.3256499999997, 567.3675703481299]

# %% [markdown]
# ### Nr. bedrooms

# %%
plot_samples(column_name = "num_bedrooms", titel = "# Bedrooms", list_var =  [1,2,3,4,5],size = (18,8))

# %%
data = new_box_plot(data = [[],[],[],[],[]],column_name = 'num_bedrooms', name_plot = ["One", "Two", "Three", "Four","Five"],titel = "# Bedrooms",list_var = [1,2,3,4,5],lim=2600,size = (18,8))
# Out:
# medians:
# [array([185.76454348, 185.76454348]), array([206.68445652, 206.68445652]), array([301.03794565, 301.03794565]), array([358.75041304, 358.75041304]), array([528.54504348, 528.54504348])]

# %%
means = []
for i in range(len(data)):
    means.append(np.mean(data[i]))
print(means)
# Out:
# [214.50861079710157, 290.4971551425992, 363.8736198390954, 430.74332644945486, 620.7279918688221]

# %% [markdown]
# ### Heating fuel

# %%
plot_samples(column_name = "heating_fuel", titel = "Heating Fuel", list_var =  ["gas","lpg_oil","elec","other"],size = (18,8))

# %%
data = new_box_plot(data = [[],[],[],[]],column_name = 'heating_fuel', name_plot = ["gas","lpg_oil","elec","other"],titel = "Heating Fuel",list_var = ["gas","lpg_oil","elec","other"],lim=2000,size = (18,8))
# Out:
# medians:
# [array([354.53395652, 354.53395652]), array([736.69975, 736.69975]), array([260.05654348, 260.05654348]), array([315.99817391, 315.99817391])]

# %%
means = []
for i in range(len(data)):
    means.append(np.mean(data[i]))
print(means)
# Out:
# [449.9720248743024, 736.69975, 527.228005434782, 370.1562944972823]

# %% [markdown]
# ### Hot water fuel

# %%
attributes[attributes["hot_water_fuel"].notnull()].hot_water_fuel.unique()
# Out:
# array(['gas', 'elec', 'other'], dtype=object)

# %%
plot_samples(column_name = "hot_water_fuel", titel = "Hot Water Fuel", list_var =  ['gas', 'elec', 'other'],size = (18,8))

# %%
data = new_box_plot(data = [[],[],[]],column_name = 'hot_water_fuel', name_plot = ['gas', 'elec', 'other'],titel = "Hot Water Fuel",list_var = ['gas', 'elec', 'other'],lim=2000,size = (18,8))
# Out:
# medians:
# [array([341.78421739, 341.78421739]), array([536.37542243, 536.37542243]), array([393.40143478, 393.40143478])]

# %%
means = []
for i in range(len(data)):
    means.append(np.mean(data[i]))
print(means)
# Out:
# [404.55813932401344, 801.229962747035, 460.2760008152171]

# %% [markdown]
# ### Boiler age

# %%
attributes[attributes["boiler_age"].notnull()].boiler_age.unique()
# Out:
# array(['new', 'old'], dtype=object)

# %%
plot_samples(column_name = "boiler_age", titel = "Boiler Age", list_var =  ['old','new'],size = (18,8))

# %%
data = new_box_plot(data = [[],[]],column_name = 'boiler_age', name_plot = ['old','new'],titel = "Boiler Age",list_var = ['old','new'],lim=2000,size = (18,8))
# Out:
# medians:
# [array([444.87878261, 444.87878261]), array([341.78421739, 341.78421739])]

# %%
means = []
for i in range(len(data)):
    means.append(np.mean(data[i]))
print(means)
# Out:
# [457.44187316852924, 472.3664705314009]

# %% [markdown]
# ### Loft insulation

# %%
attributes[attributes["loft_insulation"].notnull()].loft_insulation.unique()
# Out:
# array(['y', 'n'], dtype=object)

# %%
plot_samples(column_name = "loft_insulation", titel = "Loft Insulation", list_var =  ['y','n'],size = (18,8))

# %%
data = new_box_plot(data = [[],[]],column_name = 'loft_insulation', name_plot = ['yes','no'],titel = "Loft Insulation",list_var = ['y','n'],lim=2000,size = (18,8))
# Out:
# medians:
# [array([354.53395652, 354.53395652]), array([331.97004348, 331.97004348])]

# %%
means = []
for i in range(len(data)):
    means.append(np.mean(data[i]))
print(means)
# Out:
# [458.96024999818343, 470.7108012422358]

# %% [markdown]
# ### Wall insulation

# %%
attributes[attributes["wall_insulation"].notnull()].wall_insulation.unique()
# Out:
# array(['y_cavity', 'n', 'y_internal', 'not_sure', 'y_external'],
#       dtype=object)

# %%
plot_samples(column_name = "wall_insulation", titel = "Wall Insulation", list_var =  ['y_cavity', 'n', 'y_internal', 'not_sure', 'y_external'],size = (18,8))

# %% [markdown]
# ### Heating temperature

# %%
attributes[attributes["heating_temperature"].notnull()].heating_temperature.unique()
# Out:
# array(['18_to_20', 'above_20', 'below_18', 'not_sure'], dtype=object)

# %%
plot_samples(column_name = "heating_temperature", titel = "Heating Temperature", list_var = ['18_to_20', 'above_20', 'below_18', 'not_sure']  ,size = (18,8))

# %% [markdown]
# ### efficient_lighting_percentage

# %%
attributes[attributes["efficient_lighting_percentage"].notnull()].efficient_lighting_percentage.unique()
# Out:
# array(['0_to_25', '25_to_50', '50_to_75', '75_to_100'], dtype=object)

# %%
plot_samples(column_name = "efficient_lighting_percentage", titel = "efficient_lighting_percentage", list_var = ['0_to_25', '25_to_50', '50_to_75', '75_to_100']  ,size = (18,8))

# %% [markdown]
# ### Have to be carefull --> often not enough data and the box plot is much influenced by a couple of points.
