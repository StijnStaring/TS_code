# %%
from keras.models import load_model
from forecasting_functions import *
from os import makedirs, path

which_model = "model4_sf"
Stijn = True

if Stijn:
    path_history = "D:\AI_time_series_repos\TS_code\Forecasting\\basemodel\data\DF_three_series.csv"
    path_temperature = "D:\AI_time_series_repos\TS_code\Forecasting\\basemodel\data\DF_three_temp_series.csv"
    path_to_array = "D:\AI_time_series_repos\TS_code\Forecasting\LSTM\VM_calculating_inputs_LSTM\output_arrays_sf48"

else:
    path_history = ""
    path_temperature = ""
    path_to_array = ""

fullYeardata = pd.read_csv(path_history,index_col= "date",parse_dates= True)
names = fullYeardata.columns
av_temperature = pd.read_csv(path_temperature,index_col="meter_id",parse_dates=True)


if which_model == "model4_sf":
    makedirs("./Stateful_investigation/outputs", exist_ok=True)
    output_path = "./Stateful_investigation/outputs"
    path_txt_file = './Stateful_investigation/outputs/output_file.txt'
else:
    output_path = ""
    path_txt_file = ""

print("CSV files are loaded...")

names = fullYeardata.columns
name = names[0]
ts = time_serie(fullYeardata[name], av_temperature)
setting1 = forecast_setting(lag_value= 48, shuffle= False, nb_epoch= 2, batch_size_para= 1)
# load the LSTM input matrices
collection_trained_models = []
collection_histories = []
for model_number in range(48):
    path_X_train = path.join(path_to_array, "X_" + name + "_" + str(setting1.lag_value) + "_" + str(model_number) + "_.npy")
    X_train = np.load(path_X_train)
    path_y_train = path.join(path_to_array, "y_" + name + "_" + str(setting1.lag_value) + "_" + str(model_number) + "_.npy")
    y_train = np.load(path_y_train)
    # take the last 10 days of November as validation for the parameter search
    X_train = X_train[:-480]
    y_train = y_train[:-480]
    ts.test_true = ts.training_true[-480:]


    # X_train,y_train = unison_shuffled_copies(X_train,y_train) # no val anymore
    print("inputs found...\r\n")

    trained_model, history = build_model_stateful1(setting1, X_train, y_train, save= True)
# Out:
# Using TensorFlow backend.
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# CSV files are loaded...
# inputs found...
#
# Warning: the validation set is turned off --> activate by putting it in the fit function.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-1-37ffb19d922b> in <module>
#      52     print("inputs found...\r\n")
#      53
# ---> 54     trained_model, history = build_model_stateful1(setting1, X_train, y_train, save= True)
#      55
#      56
#
# D:\AI_time_series_repos\TS_code\Forecasting\LSTM\forecasting_functions.py in build_model_stateful1(setting, X, y, verbose_para, save, reset_after_epoch, X_val, y_val)
#     251     print("Warning: the validation set is turned off --> activate by putting it in the fit function.")
#     252     assert not setting.shuffle
# --> 253     assert setting.lag_value == 1
#     254     assert reset_after_epoch == True
#     255     history = History()
#
# AssertionError:

# %%
# should set the shuffling off



model = load_model("model.h5")
if which_model == "model3_sf":
    path_X_train_full = path.join(path_to_array, "X_" + name + "_" + str(setting1.lag_value) + "_full.npy")
    X_train_full = np.load(path_X_train_full)
all_predictions, all_references = test_set_prediction(model, setting1, ts, ts.test_true, X_train_full, True, True)

print("Model 3 prediction finished...")
outputs_model = dict()
for method in ["MSE", "RMSE", "NRMSE", "MAE", "MAPE"]:
    output: float = Switcher(method, all_predictions, all_references)
    outputs_model[method] = output
# Out:
# Warning: the validation set is turned off --> activate by putting it in the fit function.
# False
# WARNING:tensorflow:From D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/1
# 15504/15504 [==============================] - 2s 127us/step - loss: 0.0116
# Epoch number: 1/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 50us/step - loss: 0.0092
# Epoch number: 2/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 58us/step - loss: 0.0089
# Epoch number: 3/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 45us/step - loss: 0.0087
# Epoch number: 4/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 65us/step - loss: 0.0085
# Epoch number: 5/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 62us/step - loss: 0.0084
# Epoch number: 6/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 50us/step - loss: 0.0083
# Epoch number: 7/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 53us/step - loss: 0.0082
# Epoch number: 8/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 47us/step - loss: 0.0082
# Epoch number: 9/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 41us/step - loss: 0.0081
# Epoch number: 10/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 45us/step - loss: 0.0081
# Epoch number: 11/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 42us/step - loss: 0.0080
# Epoch number: 12/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 41us/step - loss: 0.0080
# Epoch number: 13/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 42us/step - loss: 0.0080
# Epoch number: 14/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 43us/step - loss: 0.0079
# Epoch number: 15/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 44us/step - loss: 0.0079
# Epoch number: 16/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 45us/step - loss: 0.0079
# Epoch number: 17/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 48us/step - loss: 0.0078
# Epoch number: 18/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 42us/step - loss: 0.0078
# Epoch number: 19/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 42us/step - loss: 0.0078
# Epoch number: 20/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 43us/step - loss: 0.0078
# Epoch number: 21/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 47us/step - loss: 0.0077
# Epoch number: 22/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 42us/step - loss: 0.0077
# Epoch number: 23/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 42us/step - loss: 0.0077
# Epoch number: 24/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 47us/step - loss: 0.0077
# Epoch number: 25/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 47us/step - loss: 0.0077
# Epoch number: 26/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 49us/step - loss: 0.0077
# Epoch number: 27/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 53us/step - loss: 0.0076
# Epoch number: 28/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 48us/step - loss: 0.0076
# Epoch number: 29/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 50us/step - loss: 0.0076
# Epoch number: 30/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 49us/step - loss: 0.0076
# Epoch number: 31/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 44us/step - loss: 0.0076
# Epoch number: 32/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 44us/step - loss: 0.0076
# Epoch number: 33/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 44us/step - loss: 0.0075
# Epoch number: 34/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 45us/step - loss: 0.0075
# Epoch number: 35/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 44us/step - loss: 0.0075
# Epoch number: 36/100.
# Epoch 1/1
#  - ETA: 0s - loss: 0.0082
# Epoch number: 37/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 44us/step - loss: 0.0075
# Epoch number: 38/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 45us/step - loss: 0.0075
# Epoch number: 39/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 44us/step - loss: 0.0074
# Epoch number: 40/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 44us/step - loss: 0.0074
# Epoch number: 41/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 44us/step - loss: 0.0074
# Epoch number: 42/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 45us/step - loss: 0.0074
# Epoch number: 43/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 46us/step - loss: 0.0074
# Epoch number: 44/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 44us/step - loss: 0.0074
# Epoch number: 45/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 46us/step - loss: 0.0073
# Epoch number: 46/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 47us/step - loss: 0.0073
# Epoch number: 47/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 44us/step - loss: 0.0073
# Epoch number: 48/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 47us/step - loss: 0.0073
# Epoch number: 49/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 50us/step - loss: 0.0073
# Epoch number: 50/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 48us/step - loss: 0.0073
# Epoch number: 51/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 45us/step - loss: 0.0072
# Epoch number: 52/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 50us/step - loss: 0.0072
# Epoch number: 53/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 48us/step - loss: 0.0072
# Epoch number: 54/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 45us/step - loss: 0.0072
# Epoch number: 55/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 46us/step - loss: 0.0072
# Epoch number: 56/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 46us/step - loss: 0.0072
# Epoch number: 57/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 51us/step - loss: 0.0072
# Epoch number: 58/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 47us/step - loss: 0.0071
# Epoch number: 59/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 47us/step - loss: 0.0071
# Epoch number: 60/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 47us/step - loss: 0.0071
# Epoch number: 61/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 48us/step - loss: 0.0071
# Epoch number: 62/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 50us/step - loss: 0.0071
# Epoch number: 63/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 49us/step - loss: 0.0071
# Epoch number: 64/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 49us/step - loss: 0.0071
# Epoch number: 65/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 54us/step - loss: 0.0071
# Epoch number: 66/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 47us/step - loss: 0.0071
# Epoch number: 67/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 48us/step - loss: 0.0070
# Epoch number: 68/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 47us/step - loss: 0.0070
# Epoch number: 69/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 51us/step - loss: 0.0070
# Epoch number: 70/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 46us/step - loss: 0.0070
# Epoch number: 71/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 50us/step - loss: 0.0070
# Epoch number: 72/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 47us/step - loss: 0.0070
# Epoch number: 73/100.
# Epoch 1/1
# 15504/15504 [==============================] - 1s 52us/step - loss: 0.0070
# Epoch number: 74/100.
# Epoch 1/1
# 14544/15504 [===========================>..] - ETA: 0s - loss: 0.0068
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-37ae28201801> in <module>
#       1 # should set the shuffling off
#       2
# ----> 3 trained_model, history = build_model_stateful1(setting1, X_train, y_train, save= True)
#       4
#       5 model = load_model("model.h5")
#
# D:\AI_time_series_repos\TS_code\Forecasting\LSTM\forecasting_functions.py in build_model_stateful1(setting, X, y, verbose_para, save, reset_after_epoch, X_val, y_val)
#     283             for k in range(setting.nb_epoch):
#     284                 # try:
# --> 285                 model.fit(x=X,y=y,epochs=1,shuffle= False, batch_size=setting.batch_size_parameter,callbacks=[early_stopping_monitor,history],verbose=verbose_para)
#     286                 # except:
#     287                     # raise Exception("Training of stateful model went wrong --> stop")
#
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# D:\ProgrammaX100\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
